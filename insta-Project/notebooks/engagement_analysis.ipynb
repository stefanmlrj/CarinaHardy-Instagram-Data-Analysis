# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 12
#      10 from engagement_metrics import calculate_engagement_metrics, aggregate_engagement_metrics
#      11 from analysis import analyze_engagement_by_time, analyze_engagement_by_content_type
# ---> 12 from visualize import plot_monthly_engagement, plot_engagement_rate
#
# File c:\Users\stefa\Documents\Codes\CarinaHardy-Instagram-Data-Analysis\insta-Project\src\visualize.py:3
#       1 import matplotlib.pyplot as plt
# ----> 3 def plot_monthly_engagement(monthly_engagement: pd.DataFrame):
#       4     """
#       5     Plots the total engagement per month.
#       6     """
#       7     monthly_engagement['engagement'].plot(kind='line', figsize=(10, 6))
#
# NameError: name 'pd' is not defined
